# %%
from pathlib import Path
import numpy as np
import torch.nn as nn
import torch
from dataclasses import dataclass
from pathlib import Path
import os
import miditok
from miditok import REMI, TokenizerConfig
from miditok.pytorch_data import DataCollator, DatasetMIDI
from torch.utils.data import DataLoader
from miditok import REMI, TokenizerConfig
from transformers import GPT2Config, GPT2LMHeadModel
from tqdm import tqdm


def train(model, optim, dataloader, ctriterion, epochs):
    model.train()
    for epoch in range(epochs):
        progress_bar = tqdm(dataloader, desc=f"Epoch {epoch + 1}/{epochs}", leave=True)
        epoch_loss = 0

        for data in progress_bar:
            optim.zero_grad()

            input_ids = data["input_ids"]
            mask = data["attention_mask"]
            out = model(input_ids, attention_mask=mask)

            shift_logits = out.logits[..., :-1, :].contiguous()
            shift_labels = input_ids[..., 1:].contiguous()
            loss = ctriterion(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))

            loss.backward()
            optim.step()

            epoch_loss += loss.item()
            progress_bar.set_postfix(loss=loss.item())

        print(f"Epoch {epoch + 1} completed with average loss: {epoch_loss / len(dataloader):.4f}")

# %%
@dataclass
class ModelConfig:
    vocab_size: int = -1
    d_model: int = 128
    n_head: int = 2
    n_layers: int = 2
    batch_size: int = 32
    max_seq_length: int = 1024
    # midi_dir = Path("pop1k7/midi_analyzed")
    train_midi_dir = Path("split")


config = ModelConfig()
tkn_config = TokenizerConfig(
    use_tempos=True,
    use_pitchdrum_tokens=False,
    beat_res={(0, 4): 16, (4, 12): 8},
)
tokenizer = REMI(tkn_config)
config.vocab_size = tokenizer.vocab_size
bos_token = tokenizer["BOS_None"]
eos_token = tokenizer["EOS_None"]
pad_token = tokenizer["PAD_None"]

gpt_config = GPT2Config(
    vocab_size=config.vocab_size,
    n_positions=config.max_seq_length,
    n_embd=config.d_model,
    n_layer=config.n_layers,
    n_head=config.n_head,
    bos_token_id=bos_token,
    eos_token_id=eos_token,
)
model = GPT2LMHeadModel(gpt_config)

# dataset setup
dataset = DatasetMIDI(
    files_paths=list(config.train_midi_dir.glob("**/*.mid")),
    tokenizer=tokenizer,
    max_seq_len=config.max_seq_length,
    bos_token_id=bos_token,
    eos_token_id=eos_token,
)

collator = DataCollator(tokenizer.pad_token_id)
dataloader = DataLoader(dataset, batch_size=config.batch_size, collate_fn=collator)

# training setup
optim = torch.optim.Adam(model.parameters())
ctriterion = nn.CrossEntropyLoss(ignore_index=pad_token)
train(model, optim=optim, dataloader=dataloader, ctriterion=ctriterion, epochs=1)
# Out:
# Epoch 1/1:   2%|▏         | 7/303 [00:20<14:39,  2.97s/it, loss=5.17]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 51
#      49 optim = torch.optim.Adam(model.parameters())
#      50 ctriterion = nn.CrossEntropyLoss(ignore_index=pad_token)
# ---> 51 train(model, optim=optim, dataloader=dataloader, ctriterion=ctriterion, epochs=1)
#
# Cell In[83], line 28, in train(model, optim, dataloader, ctriterion, epochs)
#      26 input_ids = data["input_ids"]
#      27 mask = data["attention_mask"]
# ---> 28 out = model(input_ids, attention_mask=mask)
#      30 shift_logits = out.logits[..., :-1, :].contiguous()
#      31 shift_labels = input_ids[..., 1:].contiguous()
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:1271, in GPT2LMHeadModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1263 r"""
#    1264 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1265     Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
#    1266     `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
#    1267     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#    1268 """
#    1269 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1271 transformer_outputs = self.transformer(
#    1272     input_ids,
#    1273     past_key_values=past_key_values,
#    1274     attention_mask=attention_mask,
#    1275     token_type_ids=token_type_ids,
#    1276     position_ids=position_ids,
#    1277     head_mask=head_mask,
#    1278     inputs_embeds=inputs_embeds,
#    1279     encoder_hidden_states=encoder_hidden_states,
#    1280     encoder_attention_mask=encoder_attention_mask,
#    1281     use_cache=use_cache,
#    1282     output_attentions=output_attentions,
#    1283     output_hidden_states=output_hidden_states,
#    1284     return_dict=return_dict,
#    1285 )
#    1286 hidden_states = transformer_outputs[0]
#    1288 # Set device for model parallelism
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:1132, in GPT2Model.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#    1120     outputs = self._gradient_checkpointing_func(
#    1121         block.__call__,
#    1122         hidden_states,
#    (...)
#    1129         output_attentions,
#    1130     )
#    1131 else:
# -> 1132     outputs = block(
#    1133         hidden_states,
#    1134         layer_past=layer_past,
#    1135         attention_mask=attention_mask,
#    1136         head_mask=head_mask[i],
#    1137         encoder_hidden_states=encoder_hidden_states,
#    1138         encoder_attention_mask=encoder_attention_mask,
#    1139         use_cache=use_cache,
#    1140         output_attentions=output_attentions,
#    1141     )
#    1143 hidden_states = outputs[0]
#    1144 if use_cache is True:
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:615, in GPT2Block.forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     613 residual = hidden_states
#     614 hidden_states = self.ln_1(hidden_states)
# --> 615 attn_outputs = self.attn(
#     616     hidden_states,
#     617     layer_past=layer_past,
#     618     attention_mask=attention_mask,
#     619     head_mask=head_mask,
#     620     use_cache=use_cache,
#     621     output_attentions=output_attentions,
#     622 )
#     623 attn_output = attn_outputs[0]  # output_attn: a, present, (attentions)
#     624 outputs = attn_outputs[1:]
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/music-hw3/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:545, in GPT2SdpaAttention.forward(self, hidden_states, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     541 # We dispatch to SDPA's Flash Attention or Efficient kernels via this `is_causal` if statement instead of an inline conditional assignment
#     542 # in SDPA to support both torch.compile's dynamic shapes and full graph options. An inline conditional prevents dynamic shapes from compiling.
#     543 is_causal = True if attention_mask is None and q_len > 1 and not is_cross_attention else False
# --> 545 attn_output = torch.nn.functional.scaled_dot_product_attention(
#     546     query,
#     547     key,
#     548     value,
#     549     attn_mask=attention_mask,
#     550     dropout_p=self.attn_dropout.p if self.training else 0.0,
#     551     is_causal=is_causal,
#     552 )
#     554 # Reshape outputs
#     555 attn_output = attn_output.transpose(1, 2).contiguous()
#
# KeyboardInterrupt:

# %%
sample = model.generate(max_length=config.max_seq_length)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.

# %%
id_to_vocab = {value: key for key, value in tokenizer.vocab.items()}
[id_to_vocab[id.item()] for id in sample[0]]
# Out:
# ['BOS_None',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Bar_None',
#  'Position_0',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_12',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_47',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_47',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_1.0.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_114.52',
#  'Pitch_75',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_59',
#  'Duration_1.0.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_1.0.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_1.0.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_67',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_57',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_67',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_67',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_67',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_1.0.16',
#  'Position_32',
#  'Tempo_114.52',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_1.0.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_57',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_51',
#  'Duration_1.0.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_114.52',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_1.0.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_56',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_57',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_57',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_67',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_1.0.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_57',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_114.52',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_1.0.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_1.0.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_67',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_67',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_128.06',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_51',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_57',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_57',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_59',
#  'Duration_1.0.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_67',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_57',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_1.0.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_67',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_57',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_67',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_1.0.16',
#  'Bar_None',
#  'Position_0',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_75',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_55',
#  'Velocity_55',
#  'Duration_1.0.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_67',
#  'Duration_0.8.16',
#  'Position_48',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_67',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_72',
#  'Velocity_63',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_16',
#  'Tempo_94.19',
#  'Pitch_60',
#  'Velocity_59',
#  'Duration_0.8.16',
#  'Position_32',
#  'Tempo_94.19',
#  'Pitch_58',
#  'Velocity_55',
#  ...]

# %%
# miditok.utils.split_files_for_training(
#     list(Path("/Users/stevenkao/workspace/music-hw-3/pop1k7/midi_analyzed").glob("**/*.mid")),
#     tokenizer,
#     save_dir=Path("split"),
#     max_seq_len=config.max_seq_length,
# )
